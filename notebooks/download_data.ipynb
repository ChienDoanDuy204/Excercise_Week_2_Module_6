# %%
import sys
import os
import gdown
import zipfile
from pathlib import Path

# %%
ROOT_DIR = Path.cwd().parent
ROOT_DIR
# Out:
# WindowsPath('D:/Code Module 6/Excercise_Week_2_Module_6')

# %%
# FOLDER lưu trữ data
DATA_DIR= ROOT_DIR/'data'

# %% [markdown]
# # DownLoad và giải nén DL ra thư mục data/raw

# %%
id = '17Bl09haVS6sW5_r6N8hwy4krQnddn02J'

# output tên file là nơi lưu trữ file
output = os.path.join(DATA_DIR, 'img_cls_scenes_classification.zip')

# download file
gdown.download(id=id, output=output)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=17Bl09haVS6sW5_r6N8hwy4krQnddn02J
# From (redirected): https://drive.google.com/uc?id=17Bl09haVS6sW5_r6N8hwy4krQnddn02J&confirm=t&uuid=8e427937-3ca2-4f05-8381-bfdf231102ee
# To: D:\Code Module 6\Excercise_Week_2_Module_6\data\img_cls_scenes_classification.zip
#  92%|█████████████████████████████████████████████████████████████████████████      | 236M/255M [00:20<00:01, 11.8MB/s]

# %%
with zipfile.ZipFile(output, 'r') as zip_ref:
    zip_ref.extractall(DATA_DIR)
